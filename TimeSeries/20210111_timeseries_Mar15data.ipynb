# %% [markdown]
# <a href="https://colab.research.google.com/github/KLeeDE/ResearchProj_UrbanHeat/blob/master/TimeSeries/20210111_timeseries_Mar15data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Optimal way to include longer time
# * Auto encoders
# * Fourier transform
# * Scipy fft
# * One pixel for air conditioner

# %% [markdown]
# # JPG images

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import imageio as iio
import matplotlib.pyplot as plt

# %% [markdown]
# * Pictures are taken by every 10 seconds
# * All pictures in one day (24 hr) = 8,640

# %%
# -- get file list (this may take some time)

import os
import glob

srch = os.path.join("drive", "My Drive", "urban_heat", "data", "singapore_ir", 
                    "03-15", "*.jpeg")
flist = sorted(glob.glob(srch))

print("number of files is {0}".format(len(flist)))
# Out:
# number of files is 8607

# %%
path = flist
path
# Out:
# ['drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-02.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-12.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-22.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-32.56.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-42.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-00-52.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-02.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-12.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-22.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-32.73.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-42.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-01-52.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-02.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-12.82.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-22.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-32.86.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-42.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-02-52.90.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-02.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-12.95.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-22.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-33.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-43.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-03-53.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-03.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-13.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-23.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-33.18.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-43.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-04-53.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-03.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-13.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-23.31.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-33.33.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-43.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-05-53.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-03.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-13.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-23.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-33.45.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-43.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-06-53.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-03.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-13.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-23.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-33.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-43.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-07-53.64.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-03.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-13.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-23.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-33.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-43.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-08-53.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-03.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-13.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-23.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-33.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-44.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-09-54.04.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-04.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-14.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-24.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-34.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-44.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-10-54.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-04.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-14.33.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-24.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-34.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-44.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-11-54.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-04.52.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-14.56.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-24.60.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-34.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-44.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-12-54.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-04.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-14.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-24.82.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-34.86.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-44.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-13-54.94.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-04.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-15.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-25.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-35.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-45.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-14-55.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-05.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-15.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-25.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-35.36.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-45.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-15-55.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-05.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-15.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-25.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-35.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-45.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-16-55.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-05.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-15.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-25.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-35.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-45.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-17-55.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-05.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-15.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-26.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-36.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-46.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-18-56.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-06.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-16.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-26.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-36.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-46.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-19-56.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-06.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-16.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-26.45.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-36.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-46.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-20-56.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-06.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-16.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-26.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-36.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-46.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-21-56.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-06.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-16.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-26.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-36.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-47.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-22-57.04.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-07.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-17.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-27.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-37.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-47.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-23-57.24.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-07.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-17.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-27.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-37.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-47.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-24-57.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-07.56.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-17.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-27.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-37.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-47.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-25-57.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-07.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-17.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-27.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-37.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-47.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-26-58.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-08.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-18.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-28.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-38.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-48.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-27-58.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-08.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-18.36.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-28.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-38.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-48.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-28-58.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-08.56.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-18.60.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-28.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-38.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-48.73.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-29-58.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-08.82.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-18.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-28.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-38.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-48.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-30-59.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-09.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-19.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-29.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-39.16.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-49.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-31-59.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-09.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-19.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-29.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-39.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-49.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-32-59.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-09.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-19.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-29.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-39.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-49.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-33-59.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-09.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-19.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-29.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-39.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-49.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-34-59.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-35-09.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-35-20.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-35-30.04.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-35-40.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-35-50.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-00.14.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-10.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-20.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-30.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-40.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-36-50.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-00.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-10.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-20.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-30.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-40.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-37-50.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-00.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-10.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-20.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-30.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-40.78.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-38-50.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-00.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-10.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-20.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-31.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-41.04.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-39-51.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-01.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-11.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-21.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-31.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-41.28.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-40-51.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-01.36.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-11.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-21.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-31.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-41.52.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-41-51.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-01.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-11.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-21.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-31.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-41.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-42-51.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-01.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-11.86.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-21.90.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-31.94.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-41.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-43-52.02.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-02.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-12.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-22.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-32.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-42.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-44-52.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-02.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-12.31.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-22.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-32.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-42.45.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-45-52.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-02.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-12.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-22.60.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-32.64.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-42.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-46-52.73.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-02.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-12.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-22.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-32.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-42.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-47-52.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-03.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-13.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-23.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-33.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-43.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-48-53.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-03.24.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-13.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-23.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-33.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-43.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-49-53.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-03.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-13.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-23.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-33.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-43.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-50-53.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-03.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-13.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-23.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-33.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-43.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-51-53.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-04.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-14.02.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-24.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-34.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-44.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-52-54.18.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-04.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-14.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-24.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-34.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-44.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-53-54.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-04.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-14.52.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-24.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-34.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-44.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-54-54.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-04.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-14.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-24.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-34.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-44.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-55-54.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-04.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-15.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-25.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-35.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-45.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-56-55.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-05.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-15.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-25.28.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-35.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-45.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-57-55.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-05.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-15.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-25.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-35.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-45.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-58-55.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-05.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-15.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-25.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-35.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-45.83.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T00-59-55.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-05.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-15.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-25.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-36.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-46.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-00-56.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-06.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-16.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-26.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-36.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-46.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-01-56.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-06.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-16.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-26.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-36.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-46.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-02-56.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-06.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-16.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-26.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-36.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-46.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-03-56.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-06.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-16.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-26.94.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-36.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-46.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-04-57.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-07.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-17.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-27.18.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-37.22.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-47.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-05-57.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-07.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-17.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-27.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-37.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-47.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-06-57.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-07.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-17.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-27.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-37.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-47.73.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-07-57.78.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-07.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-17.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-27.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-37.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-47.95.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-08-57.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-08.02.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-18.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-28.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-38.14.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-48.18.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-09-58.22.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-08.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-18.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-28.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-38.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-48.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-10-58.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-08.53.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-18.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-28.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-38.65.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-48.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-11-58.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-08.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-18.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-28.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-38.90.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-48.94.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-12-58.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-09.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-19.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-29.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-39.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-49.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-13-59.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-09.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-19.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-29.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-39.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-49.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-14-59.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-09.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-19.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-29.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-39.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-49.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-15-59.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-09.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-19.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-29.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-39.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-49.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-16-59.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-17-09.95.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-17-19.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-17-30.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-17-40.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-17-50.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-00.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-10.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-20.24.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-30.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-40.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-18-50.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-00.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-10.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-20.45.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-30.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-40.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-19-50.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-00.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-10.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-20.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-30.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-40.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-20-50.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-00.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-10.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-20.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-30.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-41.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-21-51.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-01.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-11.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-21.16.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-31.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-41.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-22-51.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-01.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-11.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-21.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-31.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-41.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-23-51.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-01.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-11.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-21.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-31.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-41.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-24-51.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-01.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-11.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-21.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-31.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-41.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-25-52.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-02.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-12.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-22.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-32.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-42.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-26-52.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-02.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-12.37.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-22.41.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-32.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-42.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-27-52.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-02.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-12.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-22.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-32.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-42.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-28-52.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-02.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-12.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-22.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-32.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-42.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-29-53.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-03.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-13.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-23.14.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-33.18.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-43.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-30-53.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-03.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-13.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-23.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-33.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-43.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-31-53.49.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T01-32-03.53.jpeg',
# ...
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-16-43.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-16-53.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-03.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-13.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-23.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-34.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-44.04.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-17-54.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-04.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-14.16.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-24.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-34.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-44.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-18-54.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-04.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-14.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-24.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-34.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-44.52.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-19-54.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-04.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-14.64.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-24.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-34.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-44.76.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-20-54.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-04.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-14.89.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-24.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-34.95.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-45.00.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-21-55.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-05.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-15.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-25.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-35.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-45.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-22-55.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-05.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-15.33.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-25.38.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-35.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-45.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-23-55.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-05.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-15.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-25.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-35.61.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-45.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-24-55.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-05.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-15.78.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-25.80.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-35.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-45.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-25-55.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-05.97.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-16.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-26.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-36.07.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-46.11.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-26-56.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-06.19.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-16.22.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-26.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-36.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-46.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-27-56.40.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-06.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-16.45.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-26.50.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-36.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-46.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-28-56.64.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-06.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-16.69.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-26.73.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-36.77.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-46.81.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-29-56.85.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-06.90.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-16.93.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-26.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-37.02.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-47.06.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-30-57.10.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-07.13.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-17.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-27.21.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-37.26.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-47.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-31-57.32.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-07.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-17.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-27.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-37.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-47.55.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-32-57.60.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-07.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-17.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-27.71.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-37.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-47.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-33-57.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-07.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-17.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-27.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-37.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-48.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-34-58.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-08.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-18.15.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-28.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-38.25.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-48.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-35-58.30.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-08.34.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-18.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-28.42.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-38.46.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-48.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-36-58.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-08.58.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-18.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-28.66.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-38.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-48.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-37-58.75.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-08.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-18.84.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-28.88.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-38.92.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-48.96.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-38-58.99.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-09.03.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-19.08.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-29.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-39.14.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-49.16.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-39-59.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-09.23.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-19.27.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-29.31.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-39.36.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-49.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-40-59.43.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-09.48.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-19.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-29.54.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-39.57.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-49.62.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-41-59.67.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-09.70.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-19.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-29.79.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-39.82.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-49.86.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-42-59.91.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-43-09.94.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-43-19.98.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-43-30.01.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-43-40.05.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-43-50.09.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-00.12.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-10.17.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-20.20.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-30.29.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-40.31.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-44-50.35.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-00.39.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-10.44.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-20.47.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-30.51.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-40.56.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-45-50.59.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-00.63.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-10.68.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-20.72.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-30.74.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-40.78.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-46-50.82.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-47-00.87.jpeg',
#  'drive/My Drive/urban_heat/data/singapore_ir/03-15/snap-2020-03-15T02-47-10.90.jpeg',
#  ...]

# %%
# -- get the paths and image times

# -- set file name
fname = os.path.join("drive", "My Drive", "urban_heat", "output", "paths_times_0315.csv")

# -- check that the file exists, create if it does not
if os.path.isfile(fname):
  flist_df = pd.read_csv(fname)
else:

  # -- get file list (this may take some time)
  srch = os.path.join("drive", "My Drive", "urban_heat", "data", "singapore_ir", 
                      "03-15", "*.jpeg")
  flist = sorted(glob.glob(srch))

  print("number of files is {0}".format(len(flist)))

  # -- get array of times
  times = []
  for ii in range(len(flist)):
    stmp = os.path.split(flist[ii])[1][5:-8]

    yr = stmp[:4]
    mo = stmp[5:7]
    dy = stmp[8:10]
    hr = stmp[11:13]
    mn = stmp[14:16]
    sc = stmp[17:19]

    times.append(pd.to_datetime("{0}-{1}-{2} {3}:{4}:{5}".format(yr, mo, dy, hr, mn, sc)))

  # -- convert to array
  times = np.array(times)

  # -- put into DataFrame
  flist_df = pd.DataFrame()
  flist_df["path"] = flist
  flist_df["time"] = times

  # -- write DataFrame to file
  flist_df.to_csv(fname, index=False)

# %%
# -- set the file names
pname = "/content/drive/My Drive/urban_heat/output/paths_times_0315.csv"
fpaths = pd.read_csv(pname)
fpaths = fpaths[(fpaths.time >= "2020-03-15 00:00:00") & 
                (fpaths.time < "2020-03-16 00:00:00")]
fpaths = fpaths.path.values

print("there are {0} files on 03/15/20" \
      .format(len(fpaths)))

# Increase number of images from 100 to 300
# -- only take the first 300 images
#fpaths = fpaths[:300]

# -- read in the 0th image to get the image shape
img0 = np.asarray(iio.imread(fpaths[0]))[:, :, 0] / 255.
nrow, ncol = img0.shape


# -- initialize an array to hold all of the images
imgs = np.zeros((len(fpaths), nrow, ncol))


# -- read in the images
for ii, fname in enumerate(fpaths):
  if ii % 20 == 0:
    print("working on the {0} image".format(ii))

  imgs[ii, :, :] = np.asarray(iio.imread(fname))[:, :, 0] / 255.
# Out:
# there are 8607 files on 03/15/20
# working on the 0 image
# working on the 20 image
# working on the 40 image
# working on the 60 image
# working on the 80 image
# working on the 100 image
# working on the 120 image
# working on the 140 image
# working on the 160 image
# working on the 180 image
# working on the 200 image
# working on the 220 image
# working on the 240 image
# working on the 260 image
# working on the 280 image
# working on the 300 image
# working on the 320 image
# working on the 340 image
# working on the 360 image
# working on the 380 image
# working on the 400 image
# working on the 420 image
# working on the 440 image
# working on the 460 image
# working on the 480 image
# working on the 500 image
# working on the 520 image
# working on the 540 image
# working on the 560 image
# working on the 580 image
# working on the 600 image
# working on the 620 image
# working on the 640 image
# working on the 660 image
# working on the 680 image
# working on the 700 image
# working on the 720 image
# working on the 740 image
# working on the 760 image
# working on the 780 image
# working on the 800 image
# working on the 820 image
# working on the 840 image
# working on the 860 image
# working on the 880 image
# working on the 900 image
# working on the 920 image
# working on the 940 image
# working on the 960 image
# working on the 980 image
# working on the 1000 image
# working on the 1020 image
# working on the 1040 image
# working on the 1060 image
# working on the 1080 image
# working on the 1100 image
# working on the 1120 image
# working on the 1140 image
# working on the 1160 image
# working on the 1180 image
# working on the 1200 image
# working on the 1220 image
# working on the 1240 image
# working on the 1260 image
# working on the 1280 image
# working on the 1300 image
# working on the 1320 image
# working on the 1340 image
# working on the 1360 image
# working on the 1380 image
# working on the 1400 image
# working on the 1420 image
# working on the 1440 image
# working on the 1460 image
# working on the 1480 image
# working on the 1500 image
# working on the 1520 image
# working on the 1540 image
# working on the 1560 image
# working on the 1580 image
# working on the 1600 image
# working on the 1620 image
# working on the 1640 image
# working on the 1660 image
# working on the 1680 image
# working on the 1700 image
# working on the 1720 image
# working on the 1740 image
# working on the 1760 image
# working on the 1780 image
# working on the 1800 image
# working on the 1820 image
# working on the 1840 image
# working on the 1860 image
# working on the 1880 image
# working on the 1900 image
# working on the 1920 image
# working on the 1940 image
# working on the 1960 image
# working on the 1980 image
# working on the 2000 image
# working on the 2020 image
# working on the 2040 image
# working on the 2060 image
# working on the 2080 image
# working on the 2100 image
# working on the 2120 image
# working on the 2140 image
# working on the 2160 image
# working on the 2180 image
# working on the 2200 image
# working on the 2220 image
# working on the 2240 image
# working on the 2260 image
# working on the 2280 image
# working on the 2300 image
# working on the 2320 image
# working on the 2340 image
# working on the 2360 image
# working on the 2380 image
# working on the 2400 image
# working on the 2420 image
# working on the 2440 image
# working on the 2460 image
# working on the 2480 image
# working on the 2500 image
# working on the 2520 image
# working on the 2540 image
# working on the 2560 image
# working on the 2580 image
# working on the 2600 image
# working on the 2620 image
# working on the 2640 image
# working on the 2660 image
# working on the 2680 image
# working on the 2700 image
# working on the 2720 image
# working on the 2740 image
# working on the 2760 image
# working on the 2780 image
# working on the 2800 image
# working on the 2820 image
# working on the 2840 image
# working on the 2860 image
# working on the 2880 image
# working on the 2900 image
# working on the 2920 image
# working on the 2940 image
# working on the 2960 image
# working on the 2980 image
# working on the 3000 image
# working on the 3020 image
# working on the 3040 image
# working on the 3060 image
# working on the 3080 image
# working on the 3100 image
# working on the 3120 image
# working on the 3140 image
# working on the 3160 image
# working on the 3180 image
# working on the 3200 image
# working on the 3220 image
# working on the 3240 image
# working on the 3260 image
# working on the 3280 image
# working on the 3300 image
# working on the 3320 image
# working on the 3340 image
# working on the 3360 image
# working on the 3380 image
# working on the 3400 image
# working on the 3420 image
# working on the 3440 image
# working on the 3460 image
# working on the 3480 image
# working on the 3500 image
# working on the 3520 image
# working on the 3540 image
# working on the 3560 image
# working on the 3580 image
# working on the 3600 image
# working on the 3620 image
# working on the 3640 image
# working on the 3660 image
# working on the 3680 image
# working on the 3700 image
# working on the 3720 image
# working on the 3740 image
# working on the 3760 image
# working on the 3780 image
# working on the 3800 image
# working on the 3820 image
# working on the 3840 image
# working on the 3860 image
# working on the 3880 image
# working on the 3900 image
# working on the 3920 image
# working on the 3940 image
# working on the 3960 image
# working on the 3980 image
# working on the 4000 image
# working on the 4020 image
# working on the 4040 image
# working on the 4060 image
# working on the 4080 image
# working on the 4100 image
# working on the 4120 image
# working on the 4140 image
# working on the 4160 image
# working on the 4180 image
# working on the 4200 image
# working on the 4220 image
# working on the 4240 image
# working on the 4260 image
# working on the 4280 image
# working on the 4300 image
# working on the 4320 image
# working on the 4340 image
# working on the 4360 image
# working on the 4380 image
# working on the 4400 image
# working on the 4420 image
# working on the 4440 image
# working on the 4460 image
# working on the 4480 image
# working on the 4500 image
# working on the 4520 image
# working on the 4540 image
# working on the 4560 image
# working on the 4580 image
# working on the 4600 image
# working on the 4620 image
# working on the 4640 image
# working on the 4660 image
# working on the 4680 image
# working on the 4700 image
# working on the 4720 image
# working on the 4740 image
# working on the 4760 image
# working on the 4780 image
# working on the 4800 image
# working on the 4820 image
# working on the 4840 image
# working on the 4860 image
# working on the 4880 image
# working on the 4900 image
# working on the 4920 image
# working on the 4940 image
# working on the 4960 image
# working on the 4980 image
# working on the 5000 image
# working on the 5020 image
# working on the 5040 image
# working on the 5060 image
# working on the 5080 image
# working on the 5100 image
# working on the 5120 image
# working on the 5140 image
# working on the 5160 image
# working on the 5180 image
# working on the 5200 image
# working on the 5220 image
# working on the 5240 image
# working on the 5260 image
# working on the 5280 image
# working on the 5300 image
# working on the 5320 image
# working on the 5340 image
# working on the 5360 image
# working on the 5380 image
# working on the 5400 image
# working on the 5420 image
# working on the 5440 image
# working on the 5460 image
# working on the 5480 image
# working on the 5500 image
# working on the 5520 image
# working on the 5540 image
# working on the 5560 image
# working on the 5580 image
# working on the 5600 image
# working on the 5620 image
# working on the 5640 image
# working on the 5660 image
# working on the 5680 image
# working on the 5700 image
# working on the 5720 image
# working on the 5740 image
# working on the 5760 image
# working on the 5780 image
# working on the 5800 image
# working on the 5820 image
# working on the 5840 image
# working on the 5860 image
# working on the 5880 image
# working on the 5900 image
# working on the 5920 image
# working on the 5940 image
# working on the 5960 image
# working on the 5980 image
# working on the 6000 image
# working on the 6020 image
# working on the 6040 image
# working on the 6060 image
# working on the 6080 image
# working on the 6100 image
# working on the 6120 image
# working on the 6140 image
# working on the 6160 image
# working on the 6180 image
# working on the 6200 image
# working on the 6220 image
# working on the 6240 image
# working on the 6260 image
# working on the 6280 image
# working on the 6300 image
# working on the 6320 image
# working on the 6340 image
# working on the 6360 image
# working on the 6380 image
# working on the 6400 image
# working on the 6420 image
# working on the 6440 image
# working on the 6460 image
# working on the 6480 image
# working on the 6500 image
# working on the 6520 image
# working on the 6540 image
# working on the 6560 image
# working on the 6580 image
# working on the 6600 image
# working on the 6620 image
# working on the 6640 image
# working on the 6660 image
# working on the 6680 image
# working on the 6700 image
# working on the 6720 image
# working on the 6740 image
# working on the 6760 image
# working on the 6780 image
# working on the 6800 image
# working on the 6820 image
# working on the 6840 image
# working on the 6860 image
# working on the 6880 image
# working on the 6900 image
# working on the 6920 image
# working on the 6940 image
# working on the 6960 image
# working on the 6980 image
# working on the 7000 image
# working on the 7020 image
# working on the 7040 image
# working on the 7060 image
# working on the 7080 image
# working on the 7100 image
# working on the 7120 image
# working on the 7140 image
# working on the 7160 image
# working on the 7180 image
# working on the 7200 image
# working on the 7220 image
# working on the 7240 image
# working on the 7260 image
# working on the 7280 image
# working on the 7300 image
# working on the 7320 image
# working on the 7340 image
# working on the 7360 image
# working on the 7380 image
# working on the 7400 image
# working on the 7420 image
# working on the 7440 image
# working on the 7460 image
# working on the 7480 image
# working on the 7500 image
# working on the 7520 image
# working on the 7540 image
# working on the 7560 image
# working on the 7580 image
# working on the 7600 image
# working on the 7620 image
# working on the 7640 image
# working on the 7660 image
# working on the 7680 image
# working on the 7700 image
# working on the 7720 image
# working on the 7740 image
# working on the 7760 image
# working on the 7780 image
# working on the 7800 image
# working on the 7820 image
# working on the 7840 image
# working on the 7860 image
# working on the 7880 image
# working on the 7900 image
# working on the 7920 image
# working on the 7940 image
# working on the 7960 image
# working on the 7980 image
# working on the 8000 image
# working on the 8020 image
# working on the 8040 image
# working on the 8060 image
# working on the 8080 image
# working on the 8100 image
# working on the 8120 image
# working on the 8140 image
# working on the 8160 image
# working on the 8180 image
# working on the 8200 image
# working on the 8220 image
# working on the 8240 image
# working on the 8260 image
# working on the 8280 image
# working on the 8300 image
# working on the 8320 image
# working on the 8340 image
# working on the 8360 image
# working on the 8380 image
# working on the 8400 image
# working on the 8420 image
# working on the 8440 image
# working on the 8460 image
# working on the 8480 image
# working on the 8500 image
# working on the 8520 image
# working on the 8540 image
# working on the 8560 image
# working on the 8580 image
# working on the 8600 image

# %%
imgs[ii, :, :].shape
# Out:
# (240, 320)

# %% [markdown]
# # Label pixels

# %%
# Increase labeld pixels 

# building is increased from 100 pixels to 150 pixels (1.5 times)
# window are increased from 30 pixels to 150 pixels (5 times)
# air conditioner and sky are 30 pixels as usual

# -- read in the labeled pixels 
acs = np.load("/content/drive/My Drive/urban_heat/output/acs_pix.npy")
bld = np.load("/content/drive/My Drive/urban_heat/output/bld_pix_150.npy")
sky = np.load("/content/drive/My Drive/urban_heat/output/sky_pix_20201112.npy")
win = np.load("/content/drive/My Drive/urban_heat/output/win_pix_150.npy")

# -- convert to pixel numbers
acs_col, acs_row = acs.round().astype(int).T
bld_col, bld_row = bld.round().astype(int).T
sky_col, sky_row = sky.round().astype(int).T
win_col, win_row = win.round().astype(int).T

# -- extract features from images
feat_acs = imgs[:, acs_row, acs_col].T
feat_bld = imgs[:, bld_row, bld_col].T
feat_sky = imgs[:, sky_row, sky_col].T
feat_win = imgs[:, win_row, win_col].T

# -- determine the shape of these images so that we know how to set up the convnet
acs_sh = acs.shape
bld_sh = bld.shape
sky_sh = sky.shape
win_sh = win.shape
acs_sh, bld_sh, sky_sh, win_sh
# Out:
# ((30, 2), (150, 2), (30, 2), (150, 2))

# %%
#print(sky)
#print(sky_row)
#print(sky_col)
#len(sky_row), len(sky_col)

# %%
# -- extract features from images
#feat_acs = imgs[:, acs_row, acs_col].T
#feat_bld = imgs[:, bld_row, bld_col].T
#feat_sky = imgs[:, sky_row, sky_col].T
#feat_win = imgs[:, win_row, win_col].T

# %%
plt.imshow(feat_bld, aspect="auto", interpolation="nearest")

# %%
# Plot of air conditioner 
plt.figure(figsize=(20,5))
plt.plot(imgs[:, 99, 90], color="red")
plt.title("Air conditioner (March 15, 2020)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Air conditioner (March 15, 2020)')

# %%
2000 / 360
# Out:
# 5.555555555555555

# %%
4000/360
# Out:
# 11.11111111111111

# %%
7000 / 360
# Out:
# 19.444444444444443

# %%
8000 / 360
# Out:
# 22.22222222222222

# %%
# Plot of air conditioner 
plt.figure(figsize=(20,5))
plt.plot(imgs[:, 200, 125], color="red")
plt.title("Air conditioner (March 15, 2020)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Air conditioner (March 15, 2020)')

# %%
# Plot
plt.figure(figsize=(20,5))
plt.plot(imgs[:, 10, 280], color="blue")
plt.title("Sky (March 15, 2020)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Sky (March 15, 2020)')

# %%
4000/360
# Out:
# 11.11111111111111

# %%
# Plot 
plt.figure(figsize=(20,5))
plt.plot(imgs[:, 140, 200], color="black")
plt.title("Window (March 15, 2020)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Window (March 15, 2020)')

# %%
# Plot 
plt.figure(figsize=(20,5))
plt.plot(imgs[:, 100, 175], color="orange")
plt.title("Building (March 15, 2020)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Building (March 15, 2020)')

# %%
fig, ax = plt.subplots(1, 3, figsize=[25, 8])
ax[0].imshow(imgs[20], interpolation="nearest")
ax[1].imshow(imgs[4000], interpolation="nearest")
ax[2].imshow(imgs[8000], interpolation="nearest")
fig.show()

# %% [markdown]
# # Make features

# %%
#cube = imgs[:, 99-5:99+6, 90-5:90+6]

# %%
#for ii in range(30):
  #print(feat_sky[ii].shape)

# %%
# Make features

# Air conditioner

feat_acs = []

for ii in range(len(acs_row)):
  trow = acs_row[ii]
  tcol = acs_col[ii]
  feat_acs.append(imgs[:, trow-5:trow+6, tcol-5:tcol+6].transpose(1, 2, 0))

feat_acs = np.array(feat_acs)
print(feat_acs.shape)

# Building
feat_bld = []

for ii in range(len(bld_row)):
  trow = bld_row[ii]
  tcol = bld_col[ii]
  feat_bld.append(imgs[:, trow-5:trow+6, tcol-5:tcol+6].transpose(1, 2, 0))

feat_bld = np.array(feat_bld)
print(feat_bld.shape)

# Sky
feat_sky = []

for ii in range(len(sky_row)):
  trow = sky_row[ii]
  tcol = sky_col[ii]
  feat_sky.append(imgs[:, trow-5:trow+6, tcol-5:tcol+6].transpose(1, 2, 0))

feat_sky = np.array(feat_sky)
print(feat_sky.shape)

# Window
feat_win = []

for ii in range(len(win_row)):
  trow = win_row[ii]
  tcol = win_col[ii]
  feat_win.append(imgs[:, trow-5:trow+6, tcol-5:tcol+6].transpose(1, 2, 0))

feat_win = np.array(feat_win)
print(feat_win.shape)
# Out:
# (30, 11, 11, 8607)
# (150, 11, 11, 8607)
# (30, 11, 11, 8607)
# (150, 11, 11, 8607)

# %%
# -- determine the shape of these images so that we know how to set up the convnet
#feat_acs_sh = feat_acs.shape
#feat_bld_sh = feat_bld.shape
#feat_sky_sh = feat_sky.shape
#feat_win_sh = feat_win.shape
#feat_acs_sh, feat_bld_sh, feat_sky_sh, feat_win_sh

# %%
# Plot air conditioner
ind = 9
plt.imshow(feat_acs[ind][:, :, 90], clim=[0, 1])
plt.figure(figsize=(20,5))
dum = plt.plot(feat_acs[ind].reshape(121, 8607).T, "k", lw=0.2)
dum = plt.plot(feat_acs[ind][5, 5], "r")

# %%
# Plot building
ind = 90
plt.imshow(feat_bld[ind][:, :, 90], clim=[0, 1])
plt.figure(figsize=(20,5))
dum = plt.plot(feat_bld[ind].reshape(121, 8607).T, "k", lw=0.2)
dum = plt.plot(feat_bld[ind][5, 5], "r")

# %%
# Feature
#feat = np.vstack([feat_acs, feat_bld])
feat = np.vstack([feat_acs, feat_bld, feat_sky, feat_win])
print(feat.shape)
# standardize the features
#feat = (feat - feat.mean(axis=1, keepdims=True)) / feat.std(axis=1, keepdims=True)
# Out:
# (360, 11, 11, 8607)

# %% [markdown]
# # Fourier Transformation

# %%
from scipy.fft import fft, fftfreq

# Number of sample points
N = 600

# sample spacing
T = 1.0 / 800.0

x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)

yf = fft(y)
xf = fftfreq(N, T)[:N//2]

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
from scipy.fft import fft, fftfreq

# Number of sample points
N = 600

# sample spacing
T = 1.0 / 800.0

x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

from scipy.signal import blackman
w = blackman(N)
ywf = fft(y*w)
xf = fftfreq(N, T)[:N//2]

#Plot
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', 'FFT w. window'])
plt.grid()
plt.show()

# %% [markdown]
# # Make target

# %%
# Target 
# initialize target array
labs_acs = np.zeros(acs.shape[0])
labs_bld = np.zeros(bld.shape[0]) + 1
labs_sky = np.zeros(sky.shape[0]) + 2
labs_win = np.zeros(win.shape[0]) + 3
#targ = np.hstack([labs_acs, labs_bld])
targ = np.hstack([labs_acs, labs_bld, labs_sky, labs_win])

# %% [markdown]
# # Check features and target (Prepare fore the model)

# %%
# -- create a training/testing sample
from sklearn.model_selection import train_test_split
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, test_size=0.20, random_state=314)
print(feat.shape)
print(targ.shape)
print(feat_tr.shape)
print(targ_tr.shape)
print(feat_te.shape)
print(targ_te.shape)

# %% [markdown]
# # 3D Convolutional Neural Network (Conv3D)
#
# ---

# %% [markdown]
# ## Set 3D CNN model

# %%
import numpy as np
import keras
from keras.layers import Conv3D, Flatten
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution3D, MaxPooling3D
from keras.optimizers import SGD
from keras.utils import np_utils
from keras import backend as K

# %%
# Conv3D
conv0  = keras.layers.Conv3D(32, kernel_size=(5, 5, 5), padding="same", activation="relu", input_shape=(11,11,300, 1))
pool0  = keras.layers.MaxPooling3D((2, 2, 2), strides=2)
drop0   = keras.layers.Dropout(0.5)

conv1  = keras.layers.Conv3D(64, kernel_size=(5, 5, 5), padding="same", activation="relu")
pool1  = keras.layers.MaxPooling3D(pool_size=(2, 2, 2), strides=2)
drop1   = keras.layers.Dropout(0.5)

conv2  = keras.layers.Conv3D(64, kernel_size=(5, 5, 5), padding="same", activation="relu")
pool2  = keras.layers.MaxPooling3D(pool_size=(2, 2, 2), strides=2)
drop2   = keras.layers.Dropout(0.5)

flat   = keras.layers.Flatten()
fconn  = keras.layers.Dense(1024, activation="relu")
drop3   = keras.layers.Dropout(0.5)

#output = keras.layers.Dense(2, activation="softmax")
output = keras.layers.Dense(4, activation="softmax")

layers = [conv0, pool0, drop0, flat, fconn, drop3, output]

# -- instantiate the model
model = keras.Sequential(layers)
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
#model.summary()

# %% [markdown]
# ## Train/Test set

# %%
10454400 / (288 * 11 * 11 *1)

# %%
# reshape 
feat_tr = feat_tr.reshape(feat_tr.shape[0], feat_tr.shape[1], feat_tr.shape[2], 300, 1)
feat_te = feat_te.reshape(feat_te.shape[0], feat_te.shape[1], feat_te.shape[2], 300, 1)

feat_tr.shape[0], feat_tr.shape[1], feat_tr.shape[2], feat_te.shape[0], feat_te.shape[1], feat_te.shape[2]

# %%
len(feat_tr), len(targ_tr)

# %%
# -- fit the training data
#history = model.fit(feat_tr, targ_tr, epochs=100, batch_size=10)
history = model.fit(feat_tr, targ_tr, epochs=10, batch_size=10)

# %%
loss_tr, acc_tr = model.evaluate(feat_tr, targ_tr)
loss_te, acc_te = model.evaluate(feat_te, targ_te)
print("TRAINING accuracy : {0:.4f}".format(acc_tr))
print("TESTING accuracy  : {0:.4f}".format(acc_te))

# %%
# -- plot the loss function
fig, ax = plt.subplots(figsize=(8, 5))
plt.plot(history.history["loss"])
ax.set_xlabel("epoch", fontsize=15)
ax.set_ylabel("loss", fontsize=15)
fig.show()

# %%
learning_rate = 0.001
# Compile the model
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=learning_rate), metrics=['accuracy'])

# %%
# Generate generalization metrics
#score = model.evaluate(feat_te, targ_te, verbose=0)
#print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')

# Plot history: Categorical crossentropy & Accuracy
plt.plot(history.history['loss'], label='Categorical crossentropy (training data)')
#plt.plot(history.history['val_loss'], label='Categorical crossentropy (validation data)')
plt.plot(history.history['accuracy'], label='Accuracy (training data)')
#plt.plot(history.history['val_accuracy'], label='Accuracy (validation data)')
plt.title('Model performance for 3D Keras Conv3D')
plt.ylabel('Loss value')
plt.xlabel('Number of epoch')
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Predict on all pixels

# %%
feat.shape

# %%
imgs.shape

# %%
nrow, ncol, nrow*ncol

# %%
(imgs.shape[0], nrow * ncol)

# %%
imgs.reshape(imgs.shape[0], nrow * ncol).T.shape

# %%
# -- convert images into all features
# feat_all = imgs.reshape(Nt, Nr * Nc).T, which is [Npix, Nt]
feat_1 = imgs.reshape(imgs.shape[0], nrow * ncol).T
feat_1.shape
# Need to come out as 71350

# %%
#imgs[:, 112-5:112+6, 43-5:43+6].transpose(1,2,0).reshape(11,11,300,1)

# %%
# all_pix = np.zeros([(nrow - 10) * (ncol - 10), 11, 11, 100, 1])
 #cnt = 0
 #for ii in range(5, nrow - 5): 
     #for jj in range(5, ncol - 5): 
         #all_pix[cnt] = imgs[:, ii-5:ii+5, jj-5:jj+5].tranpose(1, 2, 0).reshape(11, 11, 100, 1)
         #cnt += 1
         #all_pix.append(model.predict(all_pix[cnt])[0].argmax())

#model.predict(all_pix)[0]
#model.predict(all_pix)[0].argmax(.....)

# %%
#imgs[:, ii-5:ii+6, jj-5:jj+6].transpose(1,2,0).reshape(1,11,11,700,1)
#%timeit model.predict(x)[0].argmax()

# %%
pred_all = []

for ii in np.arange(5,nrow-5):
  print(ii)
  for jj in np.arange(5,ncol-5):
    x = imgs[:, ii-5:ii+6, jj-5:jj+6].transpose(1,2,0).reshape(1,11,11,300,1)
    pred_all.append(model.predict(x)[0].argmax())

# The total number is 234

# %%
#pred_all

# %%
pred_all = np.array(pred_all)

# %%
pred_all.shape

# %%
# model.predict(feat_all), which is [Np] -> giving result of labels (0,1,2,3)

#pred_all = model.predict(feat_all)
#pred_all = model.predict(feat_1)

# %%
plt.figure(figsize=(15, 15))
plt.imshow(imgs[0], cmap= 'gray')

# %%
# -- show the predictions
pimg = pred_all.reshape(nrow-5*2, ncol-5*2)


plt.figure(figsize=(15, 15))

plt.imshow(imgs[0, 5:nrow-5, 5:ncol-5], interpolation="nearest", cmap="gist_gray")
plt.imshow(pimg, interpolation="nearest", alpha=0.5)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(imgs[0], cmap= 'gray')
ax.set_xlim(50, 200)
ax.set_ylim(50, 0)

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(imgs[0, 5:nrow-5, 5:ncol-5], interpolation="nearest", cmap="gist_gray")
ax.imshow(imgs[0], cmap= 'gray')
ax.imshow(pimg, interpolation="nearest", alpha=0.5)
ax.set_xlim(50, 200)
ax.set_ylim(50, 0)

# %% [markdown]
# # Model evaluation

# %%
from sklearn.metrics import confusion_matrix

# -- predict the training data
pred_te = model.predict(feat_te)

# -- set a threshold for detection
thresh = 0.99

# -- determine the confusion matrix
conf = confusion_matrix(targ_te, pred_te[:, 1] > thresh)

print("confusion matrix : \n{0}".format(conf))

# %%
from sklearn.metrics import roc_curve

# -- generate ROC curve
#pred_te = model.predict(feat_te)
#roc = roc_curve(targ_te, pred_te[:, 1])

# -- plot it
#fig, ax = plt.subplots(figsize=(8, 5))
#ax.plot(roc[0], roc[1], color="darkred", lw=2)
#ax.set_xlabel("FPR")
#ax.set_ylabel("TPR")
#fig.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

# -- calculate precision and recall
pred_img = 1 * (pred_te[:, 0] < pred_te[:, 1])
prec, recall, fbeta, support = precision_recall_fscore_support(targ_te, pred_img)

print("precision : {0:.3f}".format(prec[1]))
print("recall    : {0:.3f}".format(recall[1]))
print("support   : {0}".format(support))

# %%
from sklearn.metrics import classification_report

pred_te = model.predict(feat_te)
pred_te_copy = pred_te.copy()
pred_te_copy = np.argmax(pred_te_copy, axis=1)

clas = sklearn.metrics.classification_report(targ_te, pred_te_copy) 

print(clas)

# %% [markdown]
# #Bottleneck layer output

# %%
from keras import backend as K

# %%
#input placeholder
inp = model.input

# %%
# extract the bottle neck outputs
outputs = model.layers[2].output

# %%
#Create a function to evaluate the output of the bottle neck layer for a given input
functors = K.function([inp], [outputs])

# %%
#Testing
layer_outputs = functors(feat_te[:5])

# %%
for i in range(5):
  plt.plot(layer_outputs[0][i] + i)

plt.xlabel("feature")
plt.yticks([],"")
plt.title("latent representation of the test data");

# %%
plt.plot(imgs[:, 99, 90])

# %% [markdown]
# #Fourier Transform

# %%
from scipy.fft import fft, ifft

x = ...
y = fft(x)
y

# %%
from scipy.fft import fft, fftfreq

# Number of sample points
N = 600

# sample spacing
T = 1.0 / 800.0

x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)

yf = fft(y)
xf = fftfreq(N, T)[:N//2]

plt.plot(xf, 2.0/N * np.abs(yf[0:N//2]))
plt.grid()
plt.show()

# %%
from scipy.fft import fft, fftfreq

# Number of sample points
N = 600

# sample spacing
T = 1.0 / 800.0

x = np.linspace(0.0, N*T, N, endpoint=False)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)

from scipy.signal import blackman
w = blackman(N)
ywf = fft(y*w)
xf = fftfreq(N, T)[:N//2]

#Plot
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(yf[1:N//2]), '-b')
plt.semilogy(xf[1:N//2], 2.0/N * np.abs(ywf[1:N//2]), '-r')
plt.legend(['FFT', 'FFT w. window'])
plt.grid()
plt.show()
