# %% [markdown]
# <a href="https://colab.research.google.com/github/KLeeDE/ResearchProj_UrbanHeat/blob/master/SaveIMGtoPIX/20210216_1_read_sir_images_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Reading Singapore Images**
#
# *Feb 16, 2021*
#
# ---

# %% [markdown]
# First you need to move to your `colabnb` folder,

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/urban_heat/colabnb/kmlee/
# Out:
# /content/drive/.shortcut-targets-by-id/1kvbRVbtsNfOtjX32jnBD86WXtnpvg0k-/urban_heat/colabnb/kmlee

# %% [markdown]
# now import and continue as usual.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sir_utils import *

# %%
plt.rcParams["figure.figsize"] = [10, 8]
plt.rcParams["image.interpolation"] = "nearest"

# %%
# -- read in the images
imgs = read_sir_images("2020-02-07 19:00:00", "2020-02-08 04:00:00")
# Out:
# reading filepaths...
#   reading file singapore_ir_npy/singapore_ir_130500_131000.npy (8 of 8)
# finished in 22.36s

# %%
# -- display an image
fig, ax = plt.subplots()
ax.imshow(imgs[0])
fig.show()
